# %%
import random
import pandas as pd
from pony.orm import *

# будем использовать Pony ORM
db = Database()

# создаем entities БД для таблицы со статистикой и викториной
class Statistic(db.Entity):
    login = Required(str)
    correct = Required(int)
    wrong = Required(int)
    cur_subject = Required(str)
    
class Quiz(db.Entity):
    subject = Required(str)
    question = Required(str)
    answer1 = Required(str)
    answer2 = Required(str)
    answer3 = Required(str)
    answer4 = Required(str)
    correct = Required(str)

db.bind(provider='sqlite', filename=r'C:\Users\alina\database.sqlite11', create_db=True)

set_sql_debug(True)
db.generate_mapping(create_tables=True)

# Вопросы и ответы викторин взяты из источника https://baza-otvetov.ru/
quiz = pd.read_csv('quiz_total5.csv')
quiz = quiz.astype('str')
quiz.head()

# загружаем викторину в БД и делаем commit()
for i, question in quiz.iterrows():
    q = Quiz(question=question['question'], subject=question['Subject'], answer1=str(question['answer1']), answer2=str(question['answer2']), answer3=str(question['answer3']), answer4=str(question['answer4']), correct = str(question['Correct_answer'] ))
    commit()
# Out:
# GET CONNECTION FROM THE LOCAL POOL
# PRAGMA foreign_keys = false
# BEGIN IMMEDIATE TRANSACTION
# CREATE TABLE "Quiz" (
#   "id" INTEGER PRIMARY KEY AUTOINCREMENT,
#   "subject" TEXT NOT NULL,
#   "question" TEXT NOT NULL,
#   "answer1" TEXT NOT NULL,
#   "answer2" TEXT NOT NULL,
#   "answer3" TEXT NOT NULL,
#   "answer4" TEXT NOT NULL,
#   "correct" TEXT NOT NULL
# )
#
# CREATE TABLE "Statistic" (
#   "id" INTEGER PRIMARY KEY AUTOINCREMENT,
#   "login" TEXT NOT NULL,
#   "correct" INTEGER NOT NULL,
#   "wrong" INTEGER NOT NULL,
#   "cur_subject" TEXT NOT NULL
# )
#
# SELECT "Quiz"."id", "Quiz"."subject", "Quiz"."question", "Quiz"."answer1", "Quiz"."answer2", "Quiz"."answer3", "Quiz"."answer4", "Quiz"."correct"
# FROM "Quiz" "Quiz"
# WHERE 0 = 1
#
# SELECT "Statistic"."id", "Statistic"."login", "Statistic"."correct", "Statistic"."wrong", "Statistic"."cur_subject"
# FROM "Statistic" "Statistic"
# WHERE 0 = 1
#
# COMMIT
# PRAGMA foreign_keys = true
# CLOSE CONNECTION
# GET NEW CONNECTION
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Искусство', 'В каком городе не работал великий композитор 18-го века Кристоф Виллибальд Глюк?', 'Милан', 'Берлин', 'Вена', 'Париж', 'Берлин']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Наука', 'Кто первым доказал периодичность появления комет?', 'Галилей', 'Галлей', 'Коперник', 'Кеплер', 'Галлей']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Природа и животный мир', 'Про какую летнюю погоду говорят "Вёдро" ?', 'Теплая дождливая', 'Сухая ясная', 'Прохладная дождливая', 'Длительные заморозки', 'Сухая ясная']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['География', 'С какой из этих стран Чехия не граничит?', 'Германия', 'Венгрия', 'Австрия', 'Польша', 'Венгрия']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Где в основном проживают таты?', 'Татарстан', 'Дагестан', 'Башкортостан', 'Туркменистан', 'Дагестан']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Фильмы', "Как, в переводе на русский язык, звучало бы название фильма 'Мимино'?", 'Медведь', 'Сокол', 'Гора', 'Любовь', 'Сокол']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Как называется курс парусного судна, совпадающий с направлением ветра?', 'Бейдевинд', 'Фордевинд', 'Галфинд', 'Бакштаг', 'Фордевинд']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['География', 'На вершине какой горы расположена сорокаметровая статуя Христа, являющаяся символом Рио-де-Жанейро?', 'Тупунгато', 'Корковадо', 'Уаскаран', 'Ильимани', 'Корковадо']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Какое брюхо, согласно спорной русской пословице, глухо к ученью?', 'Толстое', 'Сытое', 'Тощее', 'Пустое', 'Сытое']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Фильмы', "Благодаря какому животному Шурик познакомился с Ниной в к/ф 'Кавказская пленница'?", 'Верблюд', 'Осел', 'Конь', 'Ежик', 'Осел']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Что из этого является видом ткани?', 'Креп-лизет', 'Креп-жоржет', 'Креп-мюзет', 'Креп-жаннет', 'Креп-жоржет']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Как называется комедия В. В. Маяковского?', 'Пена', 'Клоп', 'Жук', 'Паук', 'Клоп']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Спорт', "Кто является чемпионом гонок 'Формулы-1' 1998-99 г.г.?", 'М. Шумахер', 'Хаккинен', 'Барикелло', 'Кулхард', 'Хаккинен']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', "Чье произведение легло в основу оперы Дж. Верди 'Травиата'?", 'В. Гюго', 'А.Дюма-сына', 'О. Бальзака', 'Г. Флобера', 'А.Дюма-сына']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Какой из этих городов - родина Казановы?', 'Неаполь', 'Венеция', 'Милан', 'Флоренция', 'Венеция']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Искусство', 'Кто считается основоположником кубизма?', 'В. Кандинский', 'П. Пикассо', 'Ф. Леже', 'К. Малевич', 'П. Пикассо']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['География', 'Территория какой из этих стран - наибольшая?', 'Германия', 'Япония', 'Италия', 'Финляндия', 'Япония']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Наука', 'Какая из этих кислот является витамином?', 'Молочная', 'Никотиновая', 'Яблочная', 'Янтарная', 'Никотиновая']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Наука', 'Какая очередность этих трех букв в русском алфавите правильная?', 'Ь Ы Ъ', 'Ъ Ы Ь', 'Ъ Ь Ы', 'Ь Ъ Ы', 'Ъ Ы Ь']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Какая березка стояла во поле?', 'Высокая', 'Кудрявая', 'Зеленая', 'Засохшая', 'Кудрявая']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Кто из этих знаменитых людей не является тезкой остальных?', 'Боярский', 'Лужков', 'Лермонтов', 'Горбачев', 'Лужков']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Какой ресторан находится на углу Старого и Нового Арбата?', 'Пекин', 'Прага', 'Белград', 'София', 'Прага']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Природа и животный мир', 'Какой вид березы славится красивой древесиной?', 'Курильская', 'Карельская', 'Корейская', 'Канадская', 'Карельская']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Какая поэма есть у В. В. Маяковского?', '"Свирель-губы"', '"Флейта-позвоночник"', '"Скрипка-ладони"', '"Барабан-нервы"', '"Флейта-позвоночник"']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['География', 'Какая из этих рек впадает в Азовское море?', 'Днестр', 'Дон', 'Южный Буг', 'Днепр', 'Дон']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Спорт', 'Кто из этих великих футболистов прошлого был защитником?', 'Платини', 'Беккенбауэр', 'Гарринча', 'Эйсебио', 'Беккенбауэр']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Фильмы', 'Какую икру больше всего любил Джеймс Бонд?', 'Осетровую', 'Белужью', 'Севрюжью', 'Стерляжью', 'Белужью']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Какой цвет волос был у возлюбленной Тристана Изольды, если верить Бедье?', 'Рыжий', 'Белокурый', 'Каштановый', 'Вороново крыло', 'Белокурый']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'У автомобилей какой из этих стран международный регистрационный знак DZ?', 'Белиз', 'Алжир', 'Бенин', 'Замбия', 'Алжир']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Наука', 'Одним из направлений какой религиозной философии является учение дзен?', 'Иудаизм', 'Буддизм', 'Индуизм', 'Даосизм', 'Буддизм']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Фильмы', 'В каком городе в 1932 году был проведён первый международный кинофестиваль?', 'Канн', 'Венеция', 'Париж', 'Берлин', 'Венеция']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Спорт', 'С какой фигуры начинаются соревнования по городошному спорту?', 'Пулемётное гнездо', 'Пушка', 'Артиллерия', 'Часовые', 'Пушка']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Сколько раз в сутки подзаводят часы на Спасской башне московского Кремля?', 'Один', 'Два', 'Три', 'Четыре', 'Два']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Кто получил первую Нобелевскую премию по литературе?', 'Романист', 'Поэт', 'Драматург', 'Эссеист', 'Поэт']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'С какой буквы начинаются слова, опубликованные в 16 м томе последнего издания Большой Советской энциклопедии?', 'Н', 'М', 'О', 'П', 'М']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Как назвали первую кимберлитовую трубку, открытую Ларисой Попугаевой 21 августа 1954 года?', '«Удачная»', '«Зарница»', '«Мир»', '«Советская»', '«Зарница»']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Природа и животный мир', 'В честь какого растения область Фриули-Венеция-Джулия в Италии ежегодно проводит трёхмесячный фестиваль?', 'лук', 'спаржа', 'фасоль', 'артишок', 'спаржа']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Наука', 'Как "в народе" называют химическое соединение - тринитротолуол?', 'Пластид', 'Тротил', 'Гексаген', 'Динамит', 'Тротил']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Природа и животный мир', 'У кого из "вампиров" кровь пьют только самки?', 'Летучие мыши', 'Комары', 'Пиявки', 'Клещи', 'Комары']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['География', 'В каком российском городе к его 300-летию был открыт памятник Зайцу?', 'Москва', 'Санкт-Петербург', 'Воронеж', 'Тула', 'Санкт-Петербург']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Природа и животный мир', 'Для чего зайцу его большие уши?', 'Для красоты', 'Они как рупоры, зайцу слышны даже самые тихие шорохи', 'Обмахиваться в жару', 'Для устрашения врагов-хищников', 'Они как рупоры, зайцу слышны даже самые тихие шорохи']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Природа и животный мир', 'Что обычно охотники замечают за зайцем?', 'Он трубит', 'Он барабанит', 'Он бренчит', 'Он напевает', 'Он барабанит']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Природа и животный мир', 'Что при травле зайца кричали охотники?', '«Агу!»', '«Ату!»', '«А-та-та!»', '«Ура!»', '«Ату!»']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Природа и животный мир', 'Какого зайца НЕ бывает?', 'Тумак', 'Чувак', 'Русак', 'Беляк', 'Чувак']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Природа и животный мир', 'Кто такой агути?', 'Сутулый заяц', 'Горбатый заяц', 'Лысый заяц', 'Хромой заяц', 'Горбатый заяц']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Природа и животный мир', 'Заячьей картошкой в народе называют:', 'Морковь', 'Гриб дождевик', 'Капусту', 'Кору деревьев', 'Гриб дождевик']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'В русских сказках лисичка-сестричка, коза-дереза, а зайчик-... Кто?', 'Попугайчик', 'Побегайчик', 'Петляйчик', 'Обгрызайчик', 'Побегайчик']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['География', 'Какая российская автономия полностью окружена Краснодарским краем?', 'Хакасия', 'Адыгея', 'Индушетия', 'Удмуртия', 'Адыгея']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Где жил старик со своею старухой из сказки А.С. Пушкина "Сказка о рыбаке и рыбке"?', 'в избушке', 'в землянке', 'в лачужке', 'в шалаше', 'в землянке']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Какой рыболовной снастью ловил рыбу старик из сказки А.С. Пушкина "Сказка о рыбаке и рыбке"?', 'Удочкой', 'Невод', 'Бреднем', 'Сачком', 'Невод']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'За какую плату работал Балда у попа в сказке А.С. Пушкина "Сказка о попе и работнике его Балде"?', 'Три подзатыльника', 'Три щелчка по лбу', 'Три поцелуя', 'Три рубля', 'Три щелчка по лбу']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Сколько лет рыбачил старик из сказки А.С.Пушкина "Сказка о рыбаке и рыбке"?', '43', '33', '23', '53', '33']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Спорт', 'Какую позицию на поле называют "голкипер"?', 'Защитник', 'Вратарь', 'Полузащитник', 'Нападающий', 'Вратарь']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['География', 'Официальный язык государства Израиль?', 'Фарси', 'Иврит', 'Русский', 'Арабский', 'Иврит']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Природа и животный мир', 'Как называется детеныш норки?', 'Котенок', 'Щенок', 'Белек', 'Норик', 'Щенок']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'В артериях кровь движется...?', 'Сверху вниз', 'От сердца к органам', 'От органов к сердцу', 'Снизу вверх', 'От сердца к органам']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Природа и животный мир', 'От какого дерева появляются желуди?', 'Каштан', 'Дуб', 'Ясень', 'Клен', 'Дуб']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Где муха-цокотуха нашла денежку?', 'На лугу', 'В поле', 'В лесу', 'Во дворе', 'В поле']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Как звали крысу в сказке "Золотой ключик"?', 'Чучундра', 'Шушара', 'Мымра', 'Шуршелла', 'Шушара']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Маленький мук из сказки был...?', 'Ребенком', 'Карликом', 'Лиллипутом', 'Подростком', 'Карликом']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Чем промышлял Дуремар из сказки "Золотой ключик"?', 'Лягушками', 'Пиявками', 'Бабочками', 'Стрекозами', 'Пиявками']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Где сидит Доктор Айболит?', 'В Ленинграде', 'Под деревом', 'В домике', 'В больнице', 'Под деревом']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Что такое обувница?', 'Воровка', 'Предмет мебели для обуви', 'Ложка для обуви', 'Работница обувной', 'Предмет мебели для обуви']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Природа и животный мир', 'Корюшка - это...', 'Птичка', 'Рыбка', 'Крючок', 'Растение', 'Рыбка']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['География', 'В какое море впадает Жёлтая река?', 'Ионическое море', 'Жёлтое море', 'Чёрное море', 'Каспийское море', 'Жёлтое море']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Кто был главным врагом трех поросят?', 'Троллль', 'Волк', 'Мышь', 'Мясник', 'Волк']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Наука', 'Какая планета совершает 1 оборот вокруг солнца со скоростью 47,9 км/с', 'Марс', 'Меркурий', 'Юпитер', 'Сатурн', 'Меркурий']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['География', 'Какого города нет в Казахстане?', 'Шымкент', 'Самарканд', 'Караганда', 'Пвлодар', 'Самарканд']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Кем по образованию был Антон Павлович Чехов?', 'Юрист', 'Врач', 'Учитель', 'Дипломат', 'Врач']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Искусство', 'Какой из театров Москвы носит имя А.П. Чехова?', 'Большой театр', 'МХАТ (МХТ)', 'Малый театр', 'Театр «Сатирикон»', 'МХАТ (МХТ)']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Как звали тонкого в рассказе А.П. Чехова «Толстый и тонкий»?', 'Акакий', 'Порфирий', 'Нафанаил', 'Ермолай', 'Порфирий']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Кому из обитателей палаты №6 в одноименном рассказе А.П.Чехова разрешалось выходить из флигеля и больничного двора на улицу?', 'Громову', 'Моисейке', 'Сортировщику', 'Паралитику', 'Моисейке']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Сестры с каким именем не было среди героинь чеховских «Трёх сестёр»?', 'Мария', 'Анна', 'Ирина', 'Ольга', 'Анна']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Какой из этих литературных шедевров с четвероногими героями принадлежит перу А.П. Чехова?', '«Белый пудель»', '«Каштанка»', '«Му-му»', '«Белый Бим Чёрное Ухо»', '«Каштанка»']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Рассказ А.П.Чехова о несчастном ревматике.', 'Случай из практики', 'Сапоги', 'Хирургия', 'Припадок', 'Сапоги']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'В какой пьесе А.П. Чехова герой обращался к шкафу с эпитетом «многоуважаемый»?', '«Три сестры»', '«Вишневый сад»', '«Чайка»', '«Дядя Ваня»', '«Вишневый сад»']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['География', 'В каком итальянском городе была выведена известная порода комнатных собак?', 'Сиракуза', 'Болонья', 'Падуя', 'nan', 'Болонья']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Природа и животный мир', 'Какая рыба является самым крупным пресноводным хищником?', 'Судак', 'Cом', 'Щука', 'nan', 'Cом']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Президент какой республики в 1996 году был избран президентом ФИДЕ?', 'Абхазии', 'Калмыкии', 'Башкирии', 'nan', 'Калмыкии']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Как звали младшего сына легендарного комдива Василия Ивановича Чапаева?', 'Иван', 'Аркадий', 'Евгений', 'Семён', 'Аркадий']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Чему равна сумма чисел от 0 до 100 включительно?', '3525', '5050', '1000', '7550', '5050']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Наука', 'Какой буквой физики обозначают ускорение свободного падения?', 'f', 'g', 'n', 'm', 'g']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Кто из этих российских императоров и императриц правил раньше остальных?', 'Анна Иоановна', 'Елизавета Петровна, Петр III, Екатерина II', 'Петр III', 'Екатерина II', 'Анна Иоановна']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Как называл народ медную монету в 3 копейки после 40 годов XIX века?', 'Гривенный', 'Гривенник', 'Гривна', 'Грош', 'Гривенный']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'На борту какого линкора ВМФ США был подписан акт о капитуляции Японии во второй мировой войне?', '"Айова"', '"Висконсин"', '"Миссури"', '"Нью-Джерси"', '"Миссури"']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Из произведений какого писателя физики заимствовали слово "кварк"?', 'Уильям Теккерей', 'Льюис Кэррол', 'Джеймс Джойс', 'Уильям Фолкнер', 'Джеймс Джойс']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['География', 'Какой европейский город раньше носил название Лютеция?', 'Милан', 'Тулуза', 'Париж', 'Лондон', 'Париж']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Сенатором какого штата был Ал Гор до того, как стал вице-президентом США?', 'Алабама', 'Арканзас', 'Теннесси', 'Миссисипи', 'Теннесси']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'В какие годы строился Колизей?', '580-605', '260-300', '72-80', '1085-1124', '72-80']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Изобретатель тачки?', 'Архимед', 'Пифагор', 'Паскаль', 'Эдисон', 'Паскаль']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Назовите греческого атлета, выигравшего марафон на Первой Олимпиаде нашего времени.', 'Клиридис', 'Костакис', 'Луис', 'Лумидис', 'Луис']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['География', 'Что из перечисленного является единственным колониальным владением Британии в Европе?', 'Андорра', 'Монако', 'Гибралтар', 'Люксембург', 'Гибралтар']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Облик какой женщины дошёл до наших дней благодаря скульптору Тутмесу?', 'Далилы', 'Клеопатры', 'Нефертити', 'Семирамды', 'Нефертити']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Искусство', 'Кто из этих известных актеров и режиссеров, народных артистов СССР, стал министром культуры своей страны?', 'Вия Артмане', 'Донатас Банионис', 'Богдан Ступка', 'Роберт Стуруа', 'Богдан Ступка']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Кто из этих людей не был писателем ? A: Во B: Ге C: Ле D: По', 'По', 'Во', 'Ге', 'Ле', 'Ге']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Кто стал самым молодым маршалом Советского Союза в истории СССР?', 'В.К.Блюхер', 'Г.К.Жуков', 'М.Н.Тухачевский', 'К.К.Рокоссовскийий', 'М.Н.Тухачевский']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Какой из этих городов до воссоединения Германии был в составе ГДР? A: Трир B: ВейБрауншвейгмар C: D: Ганновер', 'Трир', 'Ганновер', 'Веймар', 'Ганновер', 'Веймар']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Как назывался первый атомный ледокол СССР?', 'Свердлов', 'Сталин', 'Ленин', 'Киров', 'Ленин']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'В какой стране на население наводили ужас тонтон-макуты?', 'Парагвай', 'Куба', 'Гаити', 'Гватемала', 'Гаити']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Как называлась столица государства ацтеков?', 'Кетцалькоатль', 'Монтесума', 'Теночтитлан', 'Мехико', 'Теночтитлан']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['География', 'Назовите административный центр (столицу) штата Флорида', 'Джуно', 'Майами', 'Таллахасси', 'Сакраменто', 'Таллахасси']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Какое российское флотское звание было у Витуса Беринга?', 'Вице-адмирал', 'Контр-адмирал', 'Капитан-командор', 'Капитан 1 ранга', 'Капитан-командор']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Природа и животный мир', 'Что означает количество пятнышек у божьей коровки?', 'Пол', 'Возраст', 'Вид', 'Дату рождения', 'Вид']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Какая пара этих знаменитых писателей состоит из родных братьев?', 'Ян и Пабло Неруды', 'Ирвин и Бернард Шоу', 'Генрих и Томас Манны', 'Грэм и Александр Грины', 'Генрих и Томас Манны']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Кому и в какой глаз впился князь Гвидон в образе комара?', 'Поварихе в левый', 'Ткачихе в левый', 'Поварихе в правыйихе в правый', 'ткачихе в правый', 'Поварихе в правыйихе в правый']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Спорт', 'Игроков какой команды называют "армейцами"', 'Спартак', 'Динамо', '"ЦСКА"', 'Локомотив', '"ЦСКА"']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Природа и животный мир', 'К какому семейству рыб принадлежит пескарь?', 'Бычковые', 'Щуковые', 'Карповые', 'Колюшковые', 'Карповые']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Наука', 'Кто из этих астрономов 1 ноября 1977 года открыл Хирон - малую планету Солнечной системы?', 'Карл Сейферт', 'Дирк Брауэр', 'Чарльз Коуэл', 'Жан Пикар', 'Чарльз Коуэл']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Кто из этих русских писателей прожил самую долгую жизнь?', 'М. М. Пришвин', 'Л. Н. Толстой', 'И. А. Бунин', 'П. П. Бажов', 'И. А. Бунин']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'При введении в России табели о рангах право на личное дворянство имели даже чиновники низшего, 14-го класса. А с какого класса это право сохранилось после 1845 г.?', '10', '8', '9', '11', '9']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Какой советский орден был инкрустирован бриллиантами?', 'Орден Красного Знамени', 'Орден Ленина', 'Орден Победы', 'Орден Красной Звезды', 'Орден Победы']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Под каким названием всему миру была известна разведслужба бывшей ГДР?', 'АНБ', 'МИ-6', 'ШТАЗИ', 'МОССАД', 'ШТАЗИ']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Сказочный Доктор?', 'Фельдшер', 'Окулист', 'Айболит', 'Медик', 'Айболит']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Куда отправляет Военкомат?', 'Отдыхать', 'Отбывать', 'Служить', 'Работать', 'Служить']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Сколько циферблатов у курантов Спасской башни?', '6', '2', '4', '8', '4']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Какая из этих пород уток является яичной, а не мясной?', 'Серые украинские', 'Пекинские', 'Индийские бегуны', 'Черные белогрудые', 'Индийские бегуны']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'В каком году советские войска одержали победу в Курской битве?', '1942', '1939', '1943', '1952', '1943']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Кто изображен на правом плече Марадоны?', 'Ким Чен Ир', 'Фидель Кастро', 'Че Гевара', 'Пеле', 'Че Гевара']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Что не является знаком препинания?', 'Вопросительный знак', 'Запятая', 'Твердый знак', 'Восклицательный знак', 'Твердый знак']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Растворитель для акварельных красок?', 'Бензин', 'Спирт', 'Вода', 'nan', 'Вода']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Что такое сруб?', 'Срубленное дерево', 'Место где срублено', 'Деревянное строение', 'nan', 'Деревянное строение']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Что не является кисломолочным продуктом?', 'Сметана', 'Сыр', 'Майонез', 'Творог', 'Майонез']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['География', 'Что такое дельта реки?', 'Исток', 'Русло', 'Устье', 'nan', 'Устье']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Машинка для выравнивания грунта', 'грейдер', 'каток', 'скрепер', 'nan', 'скрепер']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Сообразительность?', 'сметка', 'сметка', 'сметка', 'сметка', 'сметка']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Какой из этих цветов не относится к тёплым?', 'Коричневый', 'Оранжевый', 'Синий', 'Красный', 'Синий']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Природа и животный мир', 'Цветы какого из этих растений не голубого цвета?', 'Колокольчик', 'Василек', 'Лютик', 'Незабудка', 'Лютик']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Что означает слово "бедуин" на арбском языке?', 'Путешественники', 'Искатели воды', 'Обитатели пустыни', 'Корабли пустыни', 'Обитатели пустыни']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'На какой вопрос никогда нельзя правда ответить "Да"?', 'Мёртв', 'Глухонемой', 'Спишь', 'nan', 'Спишь']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['География', 'Небольшие скалистые острова у невысоких берегов морей', 'ледники', 'риф', 'шхерыы', 'атоллы', 'шхерыы']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Кто стал президентом российской федерации в 2012 году?', 'Прохоров', 'Медведев', 'Путин', 'Шабельский', 'Путин']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'BanTis', 'прозвище', 'человек', 'фирма', 'фамилия', 'фирма']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Искусство', 'Какое воинское звание было у Хозе в опере "Кармен"', 'Лейтенант', 'Майор', 'Сержант', 'Солдат', 'Сержант']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Где Николай Чернышевский написал свой роман "Что делать?"', 'В ссылке', 'Дома', 'В тюрме', 'На каторге', 'В тюрме']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Ворот пиджака портной начинает отмерять с...', '3', '1', '7 позвонка', '4', '7 позвонка']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Искусство', 'Год основания группы Rammstein', '2008', '1995', '1994', '1973', '1994']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Искусство', 'Фамилия вокалиста Linkin Park', 'Шинода', 'Бенингтон', 'Беннинтгон', 'Дёрст', 'Беннинтгон']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Наука', 'Сколько атомов кислорода содержится в молекуле озона?', '2', '4', '3', '6', '3']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Сколько горошин войдут в стакан ?', 'ни сколько', 'столько скоко влязят', 'горшины не ходят', 'смотря скоко горошины', 'горшины не ходят']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Много людей сопровождают в последний путь своего родственника/знакомого. Как это называется?', 'смерть', 'упокоение', 'похороны', 'погребение', 'похороны']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Какому коню в зубы не смотрят?', 'Горем убитому', 'Жареному', 'Дарёному', 'С кариесом', 'Дарёному']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Наука', 'Уровень материнской смертности определяется как число погибших матерей на:', '1000 живорожденных', '100 000 беременностей', '100 000 живорожденных', '1000 беременностей', '100 000 живорожденных']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Искусство', 'В каком году родилась Селена Гомес?', 'В 1993 году.', 'В 1989 году.', 'В 1992 году.', 'В 1999 году.', 'В 1992 году.']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['География', 'На какой реке стоит город Саратов?', 'Дон', 'Кама', 'Волга', 'Обь', 'Волга']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'За что тянул себя барон Мюнхгаузен, чтобы выбраться из тресины?', 'за язык', 'за ухо', 'за волосы', 'за голову', 'за волосы']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Фильмы', 'Сколько родных братьев и сестёр было у Рона?', '4', '5', '6', '3', '6']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['География', 'В какой из этих столиц союзных республик раньше всего появилось метро?', 'Баку', 'Ереван', 'Тбилиси', 'Минск', 'Тбилиси']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'В форме какого животного обычно делают копилки для монет?', 'Броненосец', 'Корова', 'Свинья', 'Свинья', 'Свинья']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'На окошке сидит кошка всё как у кошки но не кошка.', 'котёнок', 'тигр', 'кот', 'дикая кошка', 'кот']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'В каком образе бог Вишну не появлялся на земле?', 'Рыбы', 'Черепахи', 'Слона', 'Вепря', 'Слона']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Как заканчивается выражение "Врет как..."?', 'Розовый слон', 'Зеленый змий', 'Сивый мерин', 'Серый заяц', 'Сивый мерин']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Какое устройство применяли во время инквизиции?', 'японские гета', 'португальский башмак', 'испанский сапог', 'русский валенок', 'испанский сапог']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['География', 'Какой из этих регионов - не на территории Италии?', 'Ломбардия', 'Тоскана', 'Савойя', 'Умбрия', 'Савойя']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Наука', 'Как по-научному называется питьевой спирт?', 'Политура', 'Метанол', 'Этанол', 'Микстура', 'Этанол']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Какая из этих премий впоследствии была переименована в Государственную премию СССР?', 'Ленинская', 'Ломоносовская', 'Сталинская', 'Нобелевская', 'Сталинская']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Наука', 'В какой области науки проявились выдающиеся способности Софьи Ковалевской?', 'Биология', 'Химия', 'Математика', 'Философия', 'Математика']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Искусство', 'Какую из этих опер написал Моцарт?', '"Сельская честь"', '"Сицилийская вечерня"', '"Свадьба Фигаро"', '"Севильский цирюльник"', '"Свадьба Фигаро"']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Какое из этих прозаических произведений, А.С.Пушкин написал от женского имени?', '"Кирджали"', '"Выстрел"', '"Рославлев"', '"Египетские ночи"', '"Рославлев"']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# ...
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Искусство', 'Кто из участников группы "АББА" был блондинкой?', 'Агнета', 'Бьёрн', 'Бенни', 'Фрида', 'Агнета']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Что такое фьючерс?', 'Вид биржевого контракта', 'Парус на яхте', 'Глагол в будущем времени', 'Холодная закуска', 'Вид биржевого контракта']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'В каком месяце 1945 года заканчивается действие повести "Семнадцать мгновений весны"?', 'Март (24)', 'Февраль', 'Апрель', 'Май', 'Март (24)']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Спорт', 'Горсть чего бросают перед выходом на ковёр борцы сумо?', 'Соли', 'Риса', 'Сои', 'Опилок бамбука', 'Соли']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Наука', 'Какой из этих металлов не относится к группе платиновых?', 'Цезий', 'Иридий', 'Палладий', 'Рутений', 'Цезий']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Какой калибр у пистолета Макарова?', '9 мм', '5.66 мм', '7.62 мм', '5.45 мм', '9 мм']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Спорт', 'Под каким номером выступали на футбольных полях великие Пеле и Марадона?', '10', '9', '8', '7', '10']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Кто был мамой Снегурочки в поэтической "весенней сказке" А. Н. Островского?', 'Весна', 'Зима', 'Вьюга', 'Луна', 'Весна']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'В какую страну Карл XII сбежал после Полтавской битвы?', 'Турция', 'Швеция', 'Дания', 'Франция', 'Турция']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Искусство', 'Чем оказался "мир" в песни В.Бутусова?', 'Повестью', 'Сказкой', 'Фантастикой', 'Рассказом', 'Повестью']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Древние египтяне полагали, что у этой птицы нет мужского пола, а самки способны зачать от ветра?', 'Коршун', 'Чайка', 'Голубь', 'Орел', 'Коршун']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Как называется плотная шерстяная ткань с наклонными рубчиками?', 'Диагональ', 'Гипотенуза', 'Перпендикуляр', 'Медиана', 'Диагональ']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Фильмы', 'Как называется один из самыx знаменитыx фильмов Альфреда Xичкока?', '"Псиxоз"', '"Мания"', '"Паранойя"', '"Бред"', '"Псиxоз"']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Из какой "оперы" слово ШЕСТОПЕР?', 'Старинное оружие', 'Реликтовая рыба', 'Вид шестерни', 'Ископаемая птица', 'Старинное оружие']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'К какой династии принадлежала английская королева Елизавета I?', 'Тюдоры', 'Виндзоры', 'Стюарты', 'Ланкастеры', 'Тюдоры']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['География', 'Какой из крупных японских городов находится на острове Хоккайдо?', 'Саппоро', 'Киото', 'Нагоя', 'Осака', 'Саппоро']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Как заканчивается признание А. С. Пушкина: "Я пишу для себя, а печатаю... "?', 'Для денег', 'Для народа', 'Для славы', 'Для критиков', 'Для денег']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Кто из этих руководителей белого движения в 1-ю мировую войну командовал Кавказской армией?', 'Юденич', 'Врангель', 'Деникин', 'Колчак', 'Юденич']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Искусство', 'В древнерусской живописи один из атрибутов архангела - тонкий жезл в его руке. Как этот жезл назывался?', 'Мерило', 'Кондак', 'Орарь', 'Лор', 'Мерило']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Как метил свои пули злодей из романа Майн Рида «Всадник без головы»?', 'К.К', 'Т.Т', 'М.М', 'С.С', 'К.К']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Фильмы', 'Съёмки какого фильма свели Бреда Питта с Анджелиной Джоли?', '"Мистер и миссис Смит"', '"Троя"', '"Счастливы вместе"', '"Лара Крофт-расхитительница гробниц"', '"Мистер и миссис Смит"']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['фильмы', 'С какой стороны от ресторана "Плакучая ива" находился туалет типа сортир? (к/ф "Бриллиантовая рука")', '50 м на север', '100 м на запад', '30 м на юг', '40 м на восток', '50 м на север']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Фильмы', 'В каком фильме прозвучала фраза: «Возьму с собой „Идиота“, чтобы не скучать в троллейбусе»?', '«Весна»', '«Весёлые ребята»', '«Цирк»', '«Волга-Волга»', '«Весна»']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Фильмы', 'Режиссер легендарного фильма "Троя"?', 'Вольфганг Петерсен', 'Стивен Спилберг', 'Сергей Бондарч', 'Джеймс Камерон', 'Вольфганг Петерсен']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Благодаря чему попали в Книгу рекордов Гиннеса странствующий альбатрос и африканский марабу?', 'Размах крыльев', 'Количество перьев', 'Дальность беспосадочного полёта', 'Вес', 'Размах крыльев']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Искусство', 'Что собирает девушка на картине Карла Брюллова «Итальянский полдень»?', 'Виноград', 'Грибы', 'Пазл', 'Марки', 'Виноград']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Какое произведение есть у Ги де Мопассана?', 'Пышка', 'Эклер', 'Слойка', 'Круассан', 'Пышка']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Назовите автора романа "Капитан Фракасс".', 'Теофил Готье', 'Рафаэль Сабатини', 'Джозеф Конрад', 'Луи Буссенар', 'Теофил Готье']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Как назывался четырехмачтовый барк "Крузенштерн" до его передачи СССР после второй мировой войны?', 'Падуя', 'Марсель', 'Гамбург', 'Барселона', 'Падуя']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Кто в годы второй Мировой войны на собственном катере выслеживал немецкие подводные лодки?', 'Хемингуэй', 'Драйзер', 'Фицджеральд', 'Фолкнер', 'Хемингуэй']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Разное', 'Какое молодёжное движение избрало своим девизом фразу «Занимайтесь любовью, а не войной»?', 'Хиппи', 'Панки', 'Металлисты', 'Рэпперы', 'Хиппи']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['География', 'Как называлась самая высокая горная вершина на территории СССР?', 'Пик Коммунизма', 'Пик Ленина', 'Пик Победы', 'Пик Революции', 'Пик Коммунизма']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Какое животное в индуизме считается священным?', 'Корова', 'Тигр', 'Обезьяна', 'Слон', 'Корова']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Искусство', 'Какого цвета скатерть на картине "Тайная вечеря" Да Винчи?', 'Белая', 'Красная', 'Зеленая', 'Черная', 'Белая']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Фильмы', 'С какими животными сражался на арене главный герой фильма 2000 г. "Гладиатор"?', 'Тигры', 'Шакалы', 'Львы', 'Леопарды', 'Тигры']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Как звали героя романа английского писателя Сэмюэла Ричардсона «Кларисса»?', 'Ловелас', 'Казанова', 'Альфонс', 'Дон Жуан', 'Ловелас']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Какой роман Достоевского экранизировал в 1951 году Акира Куросава, перенеся его действие в послевоенную Японию?', '«Идиот»', '«Преступление и наказание»', '«Бесы»', '«Братья Карамазовы»', '«Идиот»']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Какую из этих пьес написал не Е. Л. Шварц?', '"Двенадцать месяцев"', '"Голый король"', '"Снежная королева"', '"Обыкновенное чудо"', '"Двенадцать месяцев"']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Кто написал книгу "Иудейская война"?', 'Иосив Флавий', 'Тит Ливий', 'Гай Светоний', 'Плутарх', 'Иосив Флавий']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Фильмы', 'Какой из этих кинофильмов снял режиссёр Федерико Феллини?', '"Джинджер и Фред"', '"Фанни и Александр"', '"Дюль и Джим"', '"Бони и Клайд"', '"Джинджер и Фред"']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Спорт', 'Какой инвентарь используют на Олимпийских играх спортсмены, соревнующиеся в хаф-пайпе?', 'Сани', 'Лыжи', 'Коньки', 'Сноуборд', 'Сноуборд']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Искусство', 'За что Владимир Высоцкий был посмертно удостоен Государственной премии СССР?', 'За военные песни', 'За роль Гамлета', 'За все творчество', 'За роль Жеглова', 'За роль Жеглова']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Фильмы', 'Какой инструмент в фильме "Бриллиантовая рука" Гена Козодоев сломал в ресторане "Плакучая ива"?', 'аккордеон', 'саксофон', 'ксилофон', 'тромбон', 'тромбон']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Искусство', 'Сколько птиц сидит на снегу на картине Саврасова "Грачи прилетели"?', '4', '2', '3', '1', '1']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Искусство', 'Что делает царь Пётр I на картине Сурикова «Утро стрелецкой казни»?', 'стоит в карете', 'сидит на троне', 'стоит с кнутом', 'сидит на коне', 'сидит на коне']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Кто был автором книги "Основания психологии" вводившей термин "поток сознания"?', 'Анна Фрейд', 'Карл Юнг', 'Альфред Адлер', 'Уильям Джеймс', 'Уильям Джеймс']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Искусство', 'На какой из картин изображена дочь мецената Саввы Ивановича Мамонтова?', '"Всадница"', '"Осенний день. Сокольники"', '"Алёнушка"', '"Девочка с персиками"', '"Девочка с персиками"']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['История', 'Кто считается автором Книги Притчей Ветхого Завета?', 'Давид', 'Моисей', 'Самуил', 'Соломон', 'Соломон']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Наука', 'Как называется синтетическое волокно, которое разработала Лаборатория высокомолекулярных соединений Академии наук СССР?', 'капрон', 'вискоза', 'нейлон', 'лавсан', 'лавсан']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Литература', 'Как называлась первая книга, напечатанная Иваном Федоровым?', '"Четьи-Минеи"', '"Государь"', '"Домострой"', '"Апостол"', '"Апостол"']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Quiz" ("subject", "question", "answer1", "answer2", "answer3", "answer4", "correct") VALUES (?, ?, ?, ?, ?, ?, ?)
# ['Спорт', 'В каком виде спорта разыгрывают кубок Стэнли?', 'Теннис', 'Футбол', 'Велоспорт', 'Хоккей', 'Хоккей']
#
# COMMIT

# %%
# создаем бота для игры - викторины
import logging

logging.basicConfig(format='%(asctime)s - %(name)s - %(levelname)s - %(message)s', level=logging.INFO)
logger = logging.getLogger(__name__)

from telegram import Poll, KeyboardButton, InlineKeyboardButton, ReplyKeyboardMarkup, InlineKeyboardMarkup, Update
from telegram.ext import Updater, CommandHandler, PollAnswerHandler, PollHandler, MessageHandler, CallbackContext, CallbackQueryHandler


def start(update: Update, context: CallbackContext) -> None:
    # Выводим приветствие с описанием команд бота
    update.message.reply_text(f"Привет, {update.message.chat.username} ! Это интелектуальная игра - викторина! Для выбора темы викторины, нажми /choose_subject, для продолжения викторины на выбранную тему жми /next, для просмотра статистики по ответам жми /statistic !  Удачи!")
    
    # Создаем настраиваемую клавиатуру с кнопками 
    button_list1 = [KeyboardButton("/start", callback_data='/start'),
                    KeyboardButton("/choose_subject", callback_data='/choose_subject'),
                    KeyboardButton("/help", callback_data='/help'),
                    KeyboardButton("/next", callback_data='/next'),
                    KeyboardButton("/statistic", callback_data='/statistic')]
    # сборка клавиатуры из кнопок KeyboardButton
    reply_markup = ReplyKeyboardMarkup(build_menu(button_list1, n_cols=2), resize_keyboard=True)
    # отправка клавиатуры с кнопками команд в чат
    update.message.reply_text(text="Используйте кнопки на клавиатуре", reply_markup=reply_markup)
    # отправка клавиатуры для выбора тем в чат
    update.message.reply_text(text="Выберете тему для Quiz", reply_markup=buttons())

    
def buttons():
    
    # Готовим кнопки для кнопочного меню для выбора темы викторины
    button_list = [
    InlineKeyboardButton("Искусство", callback_data='Искусство'),
    InlineKeyboardButton("История", callback_data='История'),
    InlineKeyboardButton("Фильмы", callback_data='Фильмы'),
    InlineKeyboardButton("Окружающий мир", callback_data='Природа и животный мир'),
    InlineKeyboardButton("Спорт", callback_data='Спорт'),
    InlineKeyboardButton("География", callback_data='География'),
    InlineKeyboardButton("Литература", callback_data='Литература'),
    InlineKeyboardButton("Разное", callback_data='Разное'),
    InlineKeyboardButton("Наука", callback_data='Наука')]
    
    # сборка клавиатуры из кнопок `InlineKeyboardButton`
    reply_markup = InlineKeyboardMarkup(build_menu(button_list, n_cols=2), resize_keyboard=True)
    # отправка клавиатуры в чат
    return reply_markup

def choose_subject(update: Update, context: CallbackContext) -> None:
   
    # отправка клавиатуры для выбора темы викторины в чат'''
    update.message.reply_text(text="Выберете тему для Quiz", reply_markup=buttons())
  
                
def build_menu(buttons, n_cols,
               header_buttons=None,
               footer_buttons=None):
        menu = [buttons[i:i + n_cols] for i in range(0, len(buttons), n_cols)]
        if header_buttons:
            menu.insert(0, [header_buttons])
        if footer_buttons:
            menu.append([footer_buttons])
        return menu    
    
def quiz_subject(update: Update, context: CallbackContext) -> None: #(update, _):

    # получаем выбранную пользователем тему для викторины
    query = update.callback_query
    variant = query.data

    query.edit_message_text(text=f"Выбранный вариант: {variant}")   
 
    # вытаскиваем из БД случайный вопрос на заданную тему
    with db_session:
        q1 = select(q for q in Quiz if q.subject == variant)[:]
        q = select(q for q in Quiz if q.subject == variant)[:][random.randint(0,len(q1))]
        
    questions = [q.answer1, q.answer2, q.answer3, q.answer4]
    correct = q.correct
    correct_id = questions.index(correct)
    
    #  запускаем викторину
    message = update.effective_message.reply_poll(
        q.question, questions, type=Poll.QUIZ, correct_option_id=correct_id)
    
    # смотрим заведен ли это пользоватеь в таблицу БД со статистикой, если нет- то создаем его,
    # если заведен,  то обновляем его текущую выбранную тему
    with db_session:
            if len(select(q for q in Statistic if q.login == str(update.effective_chat.id))[:])==0:
                q = Statistic(login = str(update.effective_chat.id), cur_subject = variant, correct=0, wrong=0)
                commit()
            else:
                log = Statistic.get(login=str(update.effective_chat.id))
                log.cur_subject = variant
                
    # заводим информацию для дальнейшей обработки ответа
    payload = {"chat_id": update.effective_chat.id, "message_id": message.message_id}
    context.bot_data.update(payload)
    
    
def quiz_next(update: Update, context: CallbackContext) -> None: #(update, _):
    
    with db_session:
        if len(select(q for q in Statistic if q.login == str(context.bot_data['chat_id']))[:])==0:
            variant ='Разное'
        else:
            q = select(q for q in Statistic if q.login == str(context.bot_data['chat_id']))[:][0]
            variant = q.cur_subject
    # вытаскиваем случайный вопрос из БД
    with db_session:
        q1 = select(q for q in Quiz if q.subject == variant)[:]
        q = select(q for q in Quiz if q.subject == variant)[:][random.randint(0,len(q1))]
        
    questions = [q.answer1, q.answer2, q.answer3, q.answer4]
    correct = q.correct
    correct_id = questions.index(correct)
    
    # запускаем викторину
    message = update.effective_message.reply_poll(
        q.question, questions, type=Poll.QUIZ, correct_option_id=correct_id)
    
    # заводим информацию для дальнейшей обработки ответа
    payload = { "chat_id": update.effective_chat.id, "message_id": message.message_id}
    context.bot_data.update(payload)

def receive_quiz_answer(update: Update, context: CallbackContext) -> None:
    # Проверяем есть ли статистика по этому пользователю в БД, если нет, заводим
    
    
    with db_session:
        if len(select(q for q in Statistic if q.login == str(context.bot_data['chat_id']))[:])==0:
            q = Statistic(login=str(context.bot_data['chat_id']), cur_subject ='Разное', correct=0, wrong=0)
            commit()
    # id корректного варианта ответа
    correct = update.poll.correct_option_id
    # проверяем, ответил пользователь верно или нет, в зависимости от ответа обновляем его статистику в БД
    if update.poll.options[correct].voter_count == 1:
        with db_session:
            log = Statistic.get(login=str(context.bot_data['chat_id']))
            log.correct+=1
    else:
        with db_session:
            log = Statistic.get(login=str(context.bot_data['chat_id']))
            log.wrong+=1
    
    
def stat(update: Update, context: CallbackContext):
    # Выводим статистику ответов пользователя
    with db_session:
        q1 = select(q for q in Statistic if q.login==str(update.message.chat['id']))[:][0]
    update.message.reply_text(f'Статистика ответов: \n\n Правильных ответов: {q1.correct} \n Неправильных ответов:  {q1.wrong}')
        
def help_handler(update: Update, context: CallbackContext) -> None:
    # выводим сообщение при нажатии /help
    update.message.reply_text("Выберите /choose_subject для выбора темы викторины, /next для продолжения викторины на выбранную тему, /statistics для простмотра статистики по ответам, /help если нужна помощь")
    

def main() -> None:
    # Create the Updater and pass it your bot's token.
    updater = Updater("5232503148:AAHmq4oa0MvjInmvIC-Vn477_-D2GQx7VLg")
    dispatcher = updater.dispatcher
    dispatcher.add_handler(CommandHandler('start', start))
    dispatcher.add_handler(CallbackQueryHandler(quiz_subject))
    dispatcher.add_handler(CommandHandler('help', help_handler))
    dispatcher.add_handler(CommandHandler('next', quiz_next))
    dispatcher.add_handler(PollHandler(receive_quiz_answer))
    dispatcher.add_handler(CommandHandler('choose_subject', choose_subject))
    dispatcher.add_handler(CommandHandler('statistic', stat))
    
    # Запуск бота
    updater.start_polling()
    updater.idle()


if __name__ == '__main__':
    main()
# Out:
# 2022-01-29 19:03:23,585 - apscheduler.scheduler - INFO - Scheduler started
# 2022-01-29 19:05:32,930 - telegram.ext.updater - INFO - Received signal 2 (SIGINT), stopping...
# 2022-01-29 19:05:32,930 - apscheduler.scheduler - INFO - Scheduler has been shut down
